# %% [markdown]
# Import necessary library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Read the original image and show them

# %%
# Read the original image
path = "../SrcImage/tiger.jpeg"  # Replace with your image path
img_bgr = cv2.imread(path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
# print(img.shape)
# print(img_gray.shape)
img_gray = cv2.resize(img_gray, (512, 512))
# print(img_gray.shape)
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
plt.title("RGB")
plt.imshow(img_rgb)
plt.subplot(2, 2, 2)
plt.title("BGR")
plt.imshow(img_bgr)
plt.subplot(2, 2, 3)
plt.title("Gray")
plt.imshow(img_gray, cmap="gray")

# %% [markdown]
# Seperate function for decrease image resolution by 2. This function take one image as input and decrease it's resolution by 2

# %%
# import time
def decrease_resolution_by_2(sample_img):
    height, width = sample_img.shape
    new_height = height // 2
    new_width = width // 2
    downsampled_img1 = np.zeros((new_height, new_width))
    # downsampled_img1 = cv2.resize(sample_img,(new_width, new_height))
    # Perform downsampling by averaging (new_width*new_height) elements
    for i in range(new_height):
        for j in range(new_width):
            downsampled_img1[i][j] = np.mean(sample_img[i*2 : ((i*2)+2), j*2 : ((j*2)+2)])
    return downsampled_img1

# %% [markdown]
# Decreasing the image resolution by two and showing them one by one

# %%
cnt = 1
while cnt < 5:
    print(cnt)
    img_gray = decrease_resolution_by_2(img_gray)
    print(img_gray.shape)
    title = "Down Sampling " + str(cnt) + " times"
    plt.title(title)
    plt.imshow(img_gray, cmap='gray')
    plt.show()
    cnt = cnt + 1
    # time.sleep(1)
# Out:
# 1
# (256, 256)
# 2
# (128, 128)
# 3
# (64, 64)
# 4
# (32, 32)
