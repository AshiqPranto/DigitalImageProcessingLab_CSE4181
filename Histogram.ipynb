# %%
import cv2
import matplotlib.pyplot as plt

# Read the original image
path = "/media/mount/nvme0n1p4/Pranto/study/4-1/Digital Image Processing/DIP_Lab/SrcImage/tiger.jpeg"  # Replace with your image path
img_bgr = cv2.imread(path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)

# %%
flatten_img_gray = img_gray.flatten()
plt.subplot(1,2,1)
# plt.imshow(d, cmap="gray")
plt.title("Histrogram of Pixel value")
plt.hist(img_gray.ravel(),bins = 15)
plt.show()
